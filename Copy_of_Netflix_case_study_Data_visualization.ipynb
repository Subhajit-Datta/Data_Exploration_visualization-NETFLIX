# %% [markdown]
# <a href="https://colab.research.google.com/github/Subhajit1596/Data_Exploration_visualization-NETFLIX/blob/main/Copy_of_Netflix_case_study_Data_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###About NETFLIX
#
# Netflix is one of the most popular media and video streaming platforms. They have over 10000 movies or tv shows available on their platform, as of mid-2021, they have over 222M Subscribers globally. This tabular dataset consists of listings of all the movies and tv shows available on Netflix, along with details such as - cast, directors, ratings, release year, duration, etc.

# %% [markdown]
# ###Business Problem : Analyze the data and generate insights that could help Netflix in deciding which type of shows/movies to produce and how they can grow the business in different countries
# ### 1. Defining Problem Statement and Analysing basic metrics.
# importing the python libraries to solve this problem statement.
# then load the data set of netflix into this google colab.

# %%
#importing python libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#loading the dataset
# !gdown https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/000/940/original/netflix.csv
# Out:
# Downloading...
# From: https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/000/940/original/netflix.csv
# To: /content/netflix.csv
# 100% 3.40M/3.40M [00:00<00:00, 82.1MB/s]

# %%
#save the data set into df dataframe
df=pd.read_csv("netflix.csv")
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# In this process, firstly we load the dataset of "netflix.csv".
# now we check top 5 rows of this dataset.

# %%
#now we check top 5 rows of this dataframe.
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
# Obtaining information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# It will provide the details of null values of the dataframe and it also give the details about the each columns datatype.This information helps to identify all the missing values or null values of the Dataframe.
# Here we find that rating,duration and date_added are in the form of object.
# So, we have to change the rating column into int datatype, duration column must be separated for tv-series and movies differently because tv-series duration is mentioned as season format and movies into min format.
# At lastly date_added column must be convert to datetime format.But there are lots of missing values,so firstly check the null and missing values.

# %% [markdown]
# *Attributes information:*
#
# Show_id: Unique ID for every Movie / Tv Show
#
# Type: Identifier - A Movie or TV Show
#
# Title: Title of the Movie / Tv Show
#
# Director: Director of the Movie
#
# Cast: Actors involved in the movie/show
#
# Country: Country where the movie/show was produced
#
# Date_added: Date it was added on Netflix
#
# Release_year: Actual Release year of the movie/show
#
# Rating: TV Rating of the movie/show
#
# Duration: Total Duration - in minutes or number of seasons
#
# Listed_in italicized text: Genre
#
# Description: The summary description

# %% [markdown]
# ### 2. Observations on the shape of data, data types of all the attributes, conversion of categorical attributes to 'category' (If required), missing value detection, statistical summary.

# %%
#checking the numbers of rows and columns
df.shape
# Out:
# (8807, 12)

# %% [markdown]
# So,this dataframe has 8807 rows and 12 columns

# %%
#Analyzing missing values
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# Now we have to handle the missing values in different process in different forms. Mostly the missing values have been seen in director,cast and country columns.

# %% [markdown]
# *statistical summery*

# %%
df.describe()  #to check statistical summary of numerical type data
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %% [markdown]
# 75% of movies and tv shows are in between 2013 -2021
# 25% of movies and tv shows are in between 1925 -2021
# so, netflix must added old movies and tv series to increase audience who wants to see old movies, mainly a senior audience who always get nostalgic when they see some old movies.

# %%
df.describe(include = object) #to check statistical summary of categorical type data
# Out:
#        show_id   type                 title       director  \
# count     8807   8807                  8807           6173
# unique    8807      2                  8807           4528
# top         s1  Movie  Dick Johnson Is Dead  Rajiv Chilaka
# freq         1   6131                     1             19
#
#                       cast        country       date_added rating  duration  \
# count                 7982           7976             8797   8803      8804
# unique                7692            748             1767     17       220
# top     David Attenborough  United States  January 1, 2020  TV-MA  1 Season
# freq                    19           2818              109   3207      1793
#
#                            listed_in  \
# count                           8807
# unique                           514
# top     Dramas, International Movies
# freq                             362
#
#                                               description
# ...

# %% [markdown]
# We can say that United States are making most of the movies and tv series in netflix. And most commonly movies genre are international amd dramas movie.
# Here show_id and title columns are the unique factors of the dataFrame.

# %%
#checking the duplicated row in the data set.
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There is no duplicate rows of data in the dataframe.duplicate data can be changed the output of the data.

# %% [markdown]
# ###missing values

# %%
df.isnull().sum() #missing values
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
#replacing the missing values
df[["director","cast","country"]] = df[["director","cast","country"]].fillna("Not Available")
df.isnull().sum()
# Out:
# show_id          0
# type             0
# title            0
# director         0
# cast             0
# country          0
# date_added      10
# release_year     0
# rating           4
# duration         3
# listed_in        0
# description      0
# dtype: int64

# %%
#replacing the missing value for duration
df[df['duration'].isna()]
# Out:
#      show_id   type                                 title    director  \
# 5541   s5542  Movie                       Louis C.K. 2017  Louis C.K.
# 5794   s5795  Movie                 Louis C.K.: Hilarious  Louis C.K.
# 5813   s5814  Movie  Louis C.K.: Live at the Comedy Store  Louis C.K.
#
#             cast        country          date_added  release_year  rating  \
# 5541  Louis C.K.  United States       April 4, 2017          2017  74 min
# 5794  Louis C.K.  United States  September 16, 2016          2010  84 min
# 5813  Louis C.K.  United States     August 15, 2016          2015  66 min
#
#      duration listed_in                                        description
# 5541      NaN    Movies  Louis C.K. muses on religion, eternal love, gi...
# 5794      NaN    Movies  Emmy-winning comedy writer Louis C.K. brings h...
# 5813      NaN    Movies  The comic puts his trademark hilarious/thought...

# %% [markdown]
# Here we can find that duration has NaN value.And on the other side rating are given in 74 min,84min,66min in these time durations. so i have to check the dataframe. Probably think that the data for ratings changed with duration.

# %%
idx=df[df["duration"].isna()].index
df.loc[idx]=df.loc[idx].fillna(method = 'ffill', axis = 1)
df.loc[idx ,'rating'] = 'Not Available'
df.loc[idx]
# Out:
#      show_id   type                                 title    director  \
# 5541   s5542  Movie                       Louis C.K. 2017  Louis C.K.
# 5794   s5795  Movie                 Louis C.K.: Hilarious  Louis C.K.
# 5813   s5814  Movie  Louis C.K.: Live at the Comedy Store  Louis C.K.
#
#             cast        country          date_added release_year  \
# 5541  Louis C.K.  United States       April 4, 2017         2017
# 5794  Louis C.K.  United States  September 16, 2016         2010
# 5813  Louis C.K.  United States     August 15, 2016         2015
#
#              rating duration listed_in  \
# 5541  Not Available   74 min    Movies
# 5794  Not Available   84 min    Movies
# 5813  Not Available   66 min    Movies
#
#                                             description
# 5541  Louis C.K. muses on religion, eternal love, gi...
# 5794  Emmy-winning comedy writer Louis C.K. brings h...
# 5813  The comic puts his trademark hilarious/thought...

# %% [markdown]
# Replace the ratings malfunction data with duration and make the rating data columns data to "Not Available"

# %%
df.isnull().sum()
# Out:
# show_id          0
# type             0
# title            0
# director         0
# cast             0
# country          0
# date_added      10
# release_year     0
# rating           4
# duration         0
# listed_in        0
# description      0
# dtype: int64

# %%
#checking the null value for rating column
df[df["rating"].isna()]
# Out:
#      show_id     type                                              title  \
# 5989   s5990    Movie  13TH: A Conversation with Oprah Winfrey & Ava ...
# 6827   s6828  TV Show                  Gargantia on the Verdurous Planet
# 7312   s7313  TV Show                                       Little Lunch
# 7537   s7538    Movie                               My Honor Was Loyalty
#
#              director                                               cast  \
# 5989    Not Available                        Oprah Winfrey, Ava DuVernay
# 6827    Not Available  Kaito Ishikawa, Hisako Kanemoto, Ai Kayano, Ka...
# 7312    Not Available  Flynn Curry, Olivia Deeble, Madison Lu, Oisín ...
# 7537  Alessandro Pepe  Leone Frisa, Paolo Vaccarino, Francesco Miglio...
#
#             country        date_added release_year rating  duration  \
# 5989  Not Available  January 26, 2017         2017    NaN    37 min
# 6827          Japan  December 1, 2016         2013    NaN  1 Season
# ...

# %%
idx1=df[df["rating"].isna()].index
idx1
# Out:
# Int64Index([5989, 6827, 7312, 7537], dtype='int64')

# %%
df.loc[idx1 ,'rating'] = 'Not Available'
df.loc[idx1]
# Out:
#      show_id     type                                              title  \
# 5989   s5990    Movie  13TH: A Conversation with Oprah Winfrey & Ava ...
# 6827   s6828  TV Show                  Gargantia on the Verdurous Planet
# 7312   s7313  TV Show                                       Little Lunch
# 7537   s7538    Movie                               My Honor Was Loyalty
#
#              director                                               cast  \
# 5989    Not Available                        Oprah Winfrey, Ava DuVernay
# 6827    Not Available  Kaito Ishikawa, Hisako Kanemoto, Ai Kayano, Ka...
# 7312    Not Available  Flynn Curry, Olivia Deeble, Madison Lu, Oisín ...
# 7537  Alessandro Pepe  Leone Frisa, Paolo Vaccarino, Francesco Miglio...
#
#             country        date_added release_year         rating  duration  \
# 5989  Not Available  January 26, 2017         2017  Not Available    37 min
# 6827          Japan  December 1, 2016         2013  Not Available  1 Season
# ...

# %% [markdown]
# data missing value in rating column changed to "Not Available"

# %%
df.isna().sum()
# Out:
# show_id          0
# type             0
# title            0
# director         0
# cast             0
# country          0
# date_added      10
# release_year     0
# rating           0
# duration         0
# listed_in        0
# description      0
# dtype: int64

# %%
#dropping the null values from date_added column to ensure no null values in the data for perfect results
df.drop(df.loc[df["date_added"].isna()].index, axis=0, inplace=True)

# %%
df.isna().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %% [markdown]
# Total null value in every column is dropped or replaced

# %% [markdown]
# ### 3. Non-Graphical Analysis: Value counts and unique attributes.

# %%
df['type'].unique()
# Out:
# array(['Movie', 'TV Show'], dtype=object)

# %%
movies  = df.loc[df['type'] == 'Movie']
tv_series = df.loc[df['type'] == 'TV Show']

# %%
movies.head()
# Out:
#    show_id   type                             title  \
# 0       s1  Movie              Dick Johnson Is Dead
# 6       s7  Movie  My Little Pony: A New Generation
# 7       s8  Movie                           Sankofa
# 9      s10  Movie                      The Starling
# 12     s13  Movie                      Je Suis Karl
#
#                          director  \
# 0                 Kirsten Johnson
# 6   Robert Cullen, José Luis Ucha
# 7                    Haile Gerima
# 9                  Theodore Melfi
# 12            Christian Schwochow
#
#                                                  cast  \
# 0                                       Not Available
# 6   Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 9   Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12  Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
#
#                                               country          date_added  \
# ...

# %%
tv_series.head()
# Out:
#   show_id     type                  title         director  \
# 1      s2  TV Show          Blood & Water    Not Available
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans    Not Available
# 4      s5  TV Show           Kota Factory    Not Available
# 5      s6  TV Show          Midnight Mass    Mike Flanagan
#
#                                                 cast        country  \
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  Not Available
# 3                                      Not Available  Not Available
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...  Not Available
#
#            date_added release_year rating   duration  \
# 1  September 24, 2021         2021  TV-MA  2 Seasons
# 2  September 24, 2021         2021  TV-MA   1 Season
# ...

# %%
movies["duration"].value_counts()
# Out:
# 90 min     152
# 94 min     146
# 97 min     146
# 93 min     146
# 91 min     144
#           ...
# 208 min      1
# 5 min        1
# 16 min       1
# 186 min      1
# 191 min      1
# Name: duration, Length: 205, dtype: int64

# %%
tv_series["duration"].value_counts()
# Out:
# 1 Season      1793
# 2 Seasons      421
# 3 Seasons      198
# 4 Seasons       94
# 5 Seasons       64
# 6 Seasons       33
# 7 Seasons       23
# 8 Seasons       17
# 9 Seasons        9
# 10 Seasons       6
# 13 Seasons       2
# 15 Seasons       2
# 12 Seasons       2
# 17 Seasons       1
# 11 Seasons       1
# Name: duration, dtype: int64

# %%
df["date_added"].value_counts()
# Out:
# January 1, 2020      109
# November 1, 2019      89
# March 1, 2018         75
# December 31, 2019     74
# October 1, 2018       71
#                     ...
# December 4, 2016       1
# November 21, 2016      1
# November 19, 2016      1
# November 17, 2016      1
# January 11, 2020       1
# Name: date_added, Length: 1767, dtype: int64

# %% [markdown]
# now changed all the date_added columns value from object to datetime data format to extract data from year,months,date from it

# %%
df["date_added"]=pd.to_datetime(df["date_added"])

# %%
df["date_added"]
# Out:
# 0      2021-09-25
# 1      2021-09-24
# 2      2021-09-24
# 3      2021-09-24
# 4      2021-09-24
#           ...
# 8802   2019-11-20
# 8803   2019-07-01
# 8804   2019-11-01
# 8805   2020-01-11
# 8806   2019-03-02
# Name: date_added, Length: 8797, dtype: datetime64[ns]

# %%
#extract year and month from the datetime format of this data and added columns year and month into the dataframe
df['year'] = df['date_added'].dt.year
df['month'] = df['date_added'].dt.month

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water    Not Available
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans    Not Available
# 4      s5  TV Show           Kota Factory    Not Available
#
#                                                 cast        country  \
# 0                                      Not Available  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  Not Available
# 3                                      Not Available  Not Available
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added release_year rating   duration  \
# 0 2021-09-25         2020  PG-13     90 min
# 1 2021-09-24         2021  TV-MA  2 Seasons
# 2 2021-09-24         2021  TV-MA   1 Season
# ...

# %%
df["rating"].value_counts()
# Out:
# TV-MA            3205
# TV-14            2157
# TV-PG             861
# R                 799
# PG-13             490
# TV-Y7             333
# TV-Y              306
# PG                287
# TV-G              220
# NR                 79
# G                  41
# Not Available       7
# TV-Y7-FV            6
# NC-17               3
# UR                  3
# Name: rating, dtype: int64

# %%
#check unique ratings for data frame
df["rating"].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', 'Not Available', 'NR', 'TV-Y7-FV', 'UR'],
#       dtype=object)

# %%
#checking types of the netflix content
df["type"].unique()
# Out:
# array(['Movie', 'TV Show'], dtype=object)

# %% [markdown]
# Here we can find two types of content in netflix. First content is Movie another is TV show. Now seperately presents two data for movies and tv shows.

# %%
movies  = df.loc[df['type'] == 'Movie']
tv_series = df.loc[df['type'] == 'TV Show']

# %%
movies["duration"].value_counts()
# Out:
# 90 min     152
# 94 min     146
# 97 min     146
# 93 min     146
# 91 min     144
#           ...
# 208 min      1
# 5 min        1
# 16 min       1
# 186 min      1
# 191 min      1
# Name: duration, Length: 205, dtype: int64

# %%
tv_series["duration"].value_counts()
# Out:
# 1 Season      1793
# 2 Seasons      421
# 3 Seasons      198
# 4 Seasons       94
# 5 Seasons       64
# 6 Seasons       33
# 7 Seasons       23
# 8 Seasons       17
# 9 Seasons        9
# 10 Seasons       6
# 13 Seasons       2
# 15 Seasons       2
# 12 Seasons       2
# 17 Seasons       1
# 11 Seasons       1
# Name: duration, dtype: int64

# %% [markdown]
# now changed the tv_seies and movies duration format from object to integer format

# %%
movies['duration'] = movies['duration'].str[:-3]
movies['duration'] = movies['duration'].astype('int')
# Out:
# <ipython-input-147-2eaa1f41884f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['duration'] = movies['duration'].str[:-3]
# <ipython-input-147-2eaa1f41884f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['duration'] = movies['duration'].astype('int')

# %%
movies
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8801   s8802  Movie                           Zinzana
# 8802   s8803  Movie                            Zodiac
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# ...                             ...
# 8801                Majid Al Ansari
# ...

# %%
movies["duration"]
# Out:
# 0        90
# 6        91
# 7       125
# 9       104
# 12      127
#        ...
# 8801     96
# 8802    158
# 8804     88
# 8805     88
# 8806    111
# Name: duration, Length: 6131, dtype: int64

# %%
tv_series['duration'] = tv_series.duration.str[:-7]
tv_series['duration'] = tv_series['duration'].astype('int')
# Out:
# <ipython-input-150-8403d3873893>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tv_series['duration'] = tv_series.duration.str[:-7]
# <ipython-input-150-8403d3873893>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tv_series['duration'] = tv_series['duration'].astype('int')

# %%
tv_series
# Out:
#      show_id     type                  title         director  \
# 1         s2  TV Show          Blood & Water    Not Available
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans    Not Available
# 4         s5  TV Show           Kota Factory    Not Available
# 5         s6  TV Show          Midnight Mass    Mike Flanagan
# ...      ...      ...                    ...              ...
# 8795   s8796  TV Show        Yu-Gi-Oh! Arc-V    Not Available
# 8796   s8797  TV Show             Yunus Emre    Not Available
# 8797   s8798  TV Show              Zak Storm    Not Available
# 8800   s8801  TV Show     Zindagi Gulzar Hai    Not Available
# 8803   s8804  TV Show            Zombie Dumb    Not Available
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# ...

# %%
tv_series.rename({'duration': 'duration_in_seasons'} ,axis = 1 , inplace = True)
movies.rename({'duration': 'duration_in_minutes'} ,axis = 1 , inplace = True)
# Out:
# <ipython-input-152-5cb5137ae812>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tv_series.rename({'duration': 'duration_in_seasons'} ,axis = 1 , inplace = True)
# <ipython-input-152-5cb5137ae812>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies.rename({'duration': 'duration_in_minutes'} ,axis = 1 , inplace = True)

# %%
tv_series["duration_in_seasons"]
# Out:
# 1       2
# 2       1
# 3       1
# 4       2
# 5       1
#        ..
# 8795    2
# 8796    2
# 8797    3
# 8800    1
# 8803    2
# Name: duration_in_seasons, Length: 2666, dtype: int64

# %%
movies["duration_in_minutes"]
# Out:
# 0        90
# 6        91
# 7       125
# 9       104
# 12      127
#        ...
# 8801     96
# 8802    158
# 8804     88
# 8805     88
# 8806    111
# Name: duration_in_minutes, Length: 6131, dtype: int64

# %% [markdown]
# when the first movie and last movie add to the netflix

# %%
timeperiod = pd.Series((df['date_added'].min().strftime('%B %Y') , df['date_added'].max().strftime('%B %Y')))
timeperiod.index = ['first' , 'Most Recent']
timeperiod
# Out:
# first            January 2008
# Most Recent    September 2021
# dtype: object

# %% [markdown]
# most old movie and most recent movie of netflix released year

# %%
#data extraction for release years
df["release_year"].min(),df["release_year"].max()
# Out:
# (1925, 2021)

# %% [markdown]
# First relased movie in 1925 and new updated release in 2021

# %%
#different types of ratings counts in the netflix dataframe
df.groupby(['type' , 'rating'])['show_id'].count()
# Out:
# type     rating
# Movie    G                  41
#          NC-17               3
#          NR                 75
#          Not Available       5
#          PG                287
#          PG-13             490
#          R                 797
#          TV-14            1427
#          TV-G              126
#          TV-MA            2062
#          TV-PG             540
#          TV-Y              131
#          TV-Y7             139
#          TV-Y7-FV            5
#          UR                  3
# TV Show  NR                  4
#          Not Available       2
#          R                   2
#          TV-14             730
#          TV-G               94
#          TV-MA            1143
#          TV-PG             321
#          TV-Y              175
#          TV-Y7             194
#          TV-Y7-FV            1
# Name: show_id, dtype: int64

# %%
country_data = df[['show_id','type' , 'country']]
country_data.dropna(inplace = True)
country_data['country'] = country_data['country'].apply(lambda x : x.split(','))
country_data= country_data.explode('country')
country_data
# Out:
# <ipython-input-158-cde98e564118>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   country_data.dropna(inplace = True)
# <ipython-input-158-cde98e564118>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   country_data['country'] = country_data['country'].apply(lambda x : x.split(','))
#      show_id     type        country
# 0         s1    Movie  United States
# 1         s2  TV Show   South Africa
# 2         s3  TV Show  Not Available
# 3         s4  TV Show  Not Available
# 4         s5  TV Show          India
# ...

# %%
#most release netflix content country
df['country'].value_counts()
# Out:
# United States                             2812
# India                                      972
# Not Available                              830
# United Kingdom                             418
# Japan                                      244
#                                           ...
# Romania, Bulgaria, Hungary                   1
# Uruguay, Guatemala                           1
# France, Senegal, Belgium                     1
# Mexico, United States, Spain, Colombia       1
# United Arab Emirates, Jordan                 1
# Name: country, Length: 749, dtype: int64

# %% [markdown]
# Here we can say after United States,India is the more content released country for netflix.

# %%
country_data['country'] = country_data['country'].str.strip()
country_data.loc[country_data['country'] == '']
# Out:
#      show_id     type country
# 193     s194  TV Show
# 365     s366    Movie
# 1192   s1193    Movie
# 2224   s2225    Movie
# 4653   s4654    Movie
# 5925   s5926    Movie
# 7007   s7008    Movie

# %%
country_data
# Out:
#      show_id     type        country
# 0         s1    Movie  United States
# 1         s2  TV Show   South Africa
# 2         s3  TV Show  Not Available
# 3         s4  TV Show  Not Available
# 4         s5  TV Show          India
# ...      ...      ...            ...
# 8802   s8803    Movie  United States
# 8803   s8804  TV Show  Not Available
# 8804   s8805    Movie  United States
# 8805   s8806    Movie  United States
# 8806   s8807    Movie          India
#
# [10840 rows x 3 columns]

# %%
country_data = country_data.loc[country_data['country'] != '']
country_data['country'].nunique()
# Out:
# 123

# %% [markdown]
# so, there are 122 countries who make the content for netflix. 1 unique data is"Not Available". so unique countries are 123-1=122

# %% [markdown]
# Now i have to check the directors column fully for data analytics.

# %%
df['director'].value_counts()
# Out:
# Not Available                     2624
# Rajiv Chilaka                       19
# Raúl Campos, Jan Suter              18
# Suhas Kadav                         16
# Marcus Raboy                        16
#                                   ...
# Raymie Muzquiz, Stu Livingston       1
# Joe Menendez                         1
# Eric Bross                           1
# Will Eisenberg                       1
# Mozez Singh                          1
# Name: director, Length: 4529, dtype: int64

# %% [markdown]
# There are movies which are directed by multiple directors. so now we have to separate the multiple directors name properly.and count the number of directors and there movies.

# %%
dir_data= df[['show_id' , 'type' , 'director']]
dir_data.dropna(inplace = True)
dir_data['director'] = dir_data['director'].apply(lambda x : x.split(','))
dir_data
# Out:
# <ipython-input-164-25c47bde2fb4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dir_data.dropna(inplace = True)
# <ipython-input-164-25c47bde2fb4>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dir_data['director'] = dir_data['director'].apply(lambda x : x.split(','))
#      show_id     type           director
# 0         s1    Movie  [Kirsten Johnson]
# 1         s2  TV Show    [Not Available]
# 2         s3  TV Show  [Julien Leclercq]
# 3         s4  TV Show    [Not Available]
# 4         s5  TV Show    [Not Available]
# ...

# %%
dir_data = dir_data.explode('director')

# %%
dir_data['director'] = dir_data['director'].str.strip()
dir_data['director'].apply(lambda x : True if len(x) == 0 else False).value_counts()
# Out:
# False    9602
# Name: director, dtype: int64

# %%
dir_data
# Out:
#      show_id     type         director
# 0         s1    Movie  Kirsten Johnson
# 1         s2  TV Show    Not Available
# 2         s3  TV Show  Julien Leclercq
# 3         s4  TV Show    Not Available
# 4         s5  TV Show    Not Available
# ...      ...      ...              ...
# 8802   s8803    Movie    David Fincher
# 8803   s8804  TV Show    Not Available
# 8804   s8805    Movie  Ruben Fleischer
# 8805   s8806    Movie     Peter Hewitt
# 8806   s8807    Movie      Mozez Singh
#
# [9602 rows x 3 columns]

# %%
dir_data['director'].nunique()
# Out:
# 4994

# %% [markdown]
# So, unique directors are 4993. here 1 data is "Not available". so we have to check all the unique directors subtract 1 from output.
# Unique directors=4994-1=4993

# %% [markdown]
# Genre column detail analysis

# %%
genre_data = df[['show_id' , 'type', 'listed_in']]
genre_data['listed_in'] = genre_data['listed_in'].apply(lambda x : x.split(','))
genre_data = genre_data.explode('listed_in')
genre_data['listed_in'] = genre_data['listed_in'].str.strip()
# Out:
# <ipython-input-169-013cd5bce1cc>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genre_data['listed_in'] = genre_data['listed_in'].apply(lambda x : x.split(','))

# %%
genre_data["listed_in"].unique()
# Out:
# array(['Documentaries', 'International TV Shows', 'TV Dramas',
#        'TV Mysteries', 'Crime TV Shows', 'TV Action & Adventure',
#        'Docuseries', 'Reality TV', 'Romantic TV Shows', 'TV Comedies',
#        'TV Horror', 'Children & Family Movies', 'Dramas',
#        'Independent Movies', 'International Movies', 'British TV Shows',
#        'Comedies', 'Spanish-Language TV Shows', 'Thrillers',
#        'Romantic Movies', 'Music & Musicals', 'Horror Movies',
#        'Sci-Fi & Fantasy', 'TV Thrillers', "Kids' TV",
#        'Action & Adventure', 'TV Sci-Fi & Fantasy', 'Classic Movies',
#        'Anime Features', 'Sports Movies', 'Anime Series',
#        'Korean TV Shows', 'Science & Nature TV', 'Teen TV Shows',
#        'Cult Movies', 'TV Shows', 'Faith & Spirituality', 'LGBTQ Movies',
#        'Stand-Up Comedy', 'Movies', 'Stand-Up Comedy & Talk Shows',
#        'Classic & Cult TV'], dtype=object)

# %%
genre_data["listed_in"].nunique()
# Out:
# 42

# %% [markdown]
# so, we can sAY that there are 42 unique genre in the dataframe of the given Netflix dataset

# %% [markdown]
# Now i have to check cast column properly. To, know all the unique casts for the data frame

# %%
cast_data = df[['show_id' , 'type' ,'cast']]
cast_data['cast'] = cast_data['cast'].apply(lambda x : x.split(','))
cast_data= cast_data.explode('cast')
cast_data['cast'] = cast_data['cast'].str.strip()
cast_data
# Out:
# <ipython-input-172-3cf213ca216f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cast_data['cast'] = cast_data['cast'].apply(lambda x : x.split(','))
#      show_id     type                   cast
# 0         s1    Movie          Not Available
# 1         s2  TV Show             Ama Qamata
# 1         s2  TV Show            Khosi Ngema
# 1         s2  TV Show          Gail Mabalane
# 1         s2  TV Show         Thabang Molaba
# ...      ...      ...                    ...
# 8806   s8807    Movie       Manish Chaudhary
# 8806   s8807    Movie           Meghna Malik
# 8806   s8807    Movie          Malkeet Rauni
# 8806   s8807    Movie         Anita Shabdish
# 8806   s8807    Movie  Chittaranjan Tripathy
#
# [64882 rows x 3 columns]

# %%
cast_data["cast"].unique()
# Out:
# array(['Not Available', 'Ama Qamata', 'Khosi Ngema', ..., 'Malkeet Rauni',
#        'Anita Shabdish', 'Chittaranjan Tripathy'], dtype=object)

# %%
cast_data["cast"].nunique()
# Out:
# 36404

# %% [markdown]
# So there are 36403 unique actor and actress in the data frame who has down some content with netflix.
# unique cast=36404-1=36403, because 1 cast was written as "Not Available

# %%
x = cast_data.groupby(['cast' , 'type'])['show_id'].count().reset_index()
x.pivot(index = 'cast' , columns = 'type' , values = 'show_id').sort_values('TV Show' , ascending = False)
# Out:
# type              Movie  TV Show
# cast
# Not Available     475.0    350.0
# Takahiro Sakurai    7.0     25.0
# Yuki Kaji          10.0     19.0
# Ai Kayano           2.0     17.0
# Junichi Suwabe      4.0     17.0
# ...                 ...      ...
# Şerif Sezer         1.0      NaN
# Şevket Çoruh        1.0      NaN
# Şinasi Yurtsever    3.0      NaN
# Şükran Ovalı        1.0      NaN
# Ṣọpẹ́ Dìrísù        1.0      NaN
#
# [36404 rows x 2 columns]

# %% [markdown]
# ### 4. Visual Analysis - Univariate, Bivariate after pre-processing of the data.

# %% [markdown]
# Distribution of content of different types
#
# *Univariate Analysis*

# %%
types = df["type"].value_counts()
plt.pie(types,labels=types.index,autopct='%1.1f%%',colors = ['blue' , 'orange'])
plt.title('Total_Movies and TV Shows')
plt.show()

# %% [markdown]
# #Oberservation
# From here we can say that in Netflix approx 70 percent contents are movies and 30% are tv shows. So, contents of comsumption in movies is still higher than tv shows.

# %% [markdown]
# year wise content present in netflix

# %%
content_data = df.groupby(['type' , 'release_year'])['show_id'].count().reset_index()
content_data.rename({'show_id' : 'total movies/TV shows'}, axis = 1 , inplace = True)
content_data
# Out:
#         type  release_year  total movies/TV shows
# 0      Movie          1942                      2
# 1      Movie          1943                      3
# 2      Movie          1944                      3
# 3      Movie          1945                      3
# 4      Movie          1946                      1
# ..       ...           ...                    ...
# 114  TV Show          2017                    265
# 115  TV Show          2018                    379
# 116  TV Show          2019                    397
# 117  TV Show          2020                    436
# 118  TV Show          2021                    315
#
# [119 rows x 3 columns]

# %%
plt.figure(figsize = (12,5))
sns.lineplot(data = content_data , x = 'release_year' , y = 'total movies/TV shows' , hue = 'type' , marker = 'o'  , ms = 6 )
plt.xlabel('release_year' , fontsize = 12)
plt.ylabel('total movies/TV shows' , fontsize = 12)
plt.title('total movies and TV shows by the release_year' , fontsize = 12)
plt.xlim( left = 2000 , right = 2021)
plt.xticks(np.arange(2000 , 2021 , 2))
plt.show()

# %% [markdown]
# #Observation
#  from this graph we can say that in 2018 is the highest number of contents are released.Then from 2018 there is a drop in the content.
#
#  But in 2020,Netflix is more likely to published tv shows greater than movies.

# %% [markdown]
# How has the number of movies/TV shows added on Netflix per year changed over the time?

# %%
year_data = df.groupby(['year' ,'type' ])['show_id'].count().reset_index()
year_data.rename({'show_id' : 'total movies/TV shows'}, axis = 1 , inplace = True)
year_data
# Out:
#     year     type  total movies/TV shows
# 0   2008    Movie                      1
# 1   2008  TV Show                      1
# 2   2009    Movie                      2
# 3   2010    Movie                      1
# 4   2011    Movie                     13
# 5   2012    Movie                      3
# 6   2013    Movie                      6
# 7   2013  TV Show                      5
# 8   2014    Movie                     19
# 9   2014  TV Show                      5
# 10  2015    Movie                     56
# 11  2015  TV Show                     26
# 12  2016    Movie                    253
# 13  2016  TV Show                    176
# 14  2017    Movie                    839
# 15  2017  TV Show                    349
# 16  2018    Movie                   1237
# 17  2018  TV Show                    412
# 18  2019    Movie                   1424
# 19  2019  TV Show                    592
# 20  2020    Movie                   1284
# 21  2020  TV Show                    595
# ...

# %%
plt.figure(figsize = (12,5))
sns.lineplot(data = year_data , x = 'year' , y = 'total movies/TV shows' , hue = 'type', marker = 'o'  , ms = 6)
plt.xlabel('year' , fontsize = 12)
plt.ylabel('total movies/TV shows' , fontsize = 12)
plt.title('total movies and TV shows by the yearwise' , fontsize = 12)
plt.show()

# %% [markdown]
# #Observation
#   The content added on the Netflix surged drastically after 2015.
#
#   2019 marks the highest number of movies and TV shows added on the Netflix.
#
#   After the year ofThe content added on the Netflix surged drastically after 2015.

# %% [markdown]
# Now total movies and Tv shows of top 10 directors present in visual format

# %%
# total Movies directed by top 10 directors
top_10_dir = dir_data["director"].value_counts().head(10).index
df_new = dir_data.loc[dir_data['director'].isin(top_10_dir)]
df_new=df_new.drop(df_new[df_new["director"]=="Not Available"].index,axis=0)

# %%
df_new
# Out:
#      show_id   type             director
# 406     s407  Movie        Rajiv Chilaka
# 407     s408  Movie        Rajiv Chilaka
# 408     s409  Movie        Rajiv Chilaka
# 409     s410  Movie        Rajiv Chilaka
# 410     s411  Movie        Rajiv Chilaka
# ...      ...    ...                  ...
# 7513   s7514  Movie          Suhas Kadav
# 7820   s7821  Movie      Martin Scorsese
# 8272   s8273  Movie      Martin Scorsese
# 8735   s8736  Movie      Martin Scorsese
# 8789   s8790  Movie  Cathy Garcia-Molina
#
# [146 rows x 3 columns]

# %%
plt.figure(figsize= (8 , 6))
sns.countplot(data = df_new , y = 'director' , order = top_10_dir , orient = 'v')
plt.xlabel('total_movies/TV shows' , fontsize = 12)
plt.xlabel('Movies/TV shows count')
plt.ylabel('Directors' , fontsize = 12)
plt.title('Total_movies/TVshows_by_director')
plt.show()

# %% [markdown]
# #Observation
#    From here we can say that top director in Netflix data is Rajib Chilaka.

# %%
dir_data
# Out:
#      show_id     type         director
# 0         s1    Movie  Kirsten Johnson
# 1         s2  TV Show    Not Available
# 2         s3  TV Show  Julien Leclercq
# 3         s4  TV Show    Not Available
# 4         s5  TV Show    Not Available
# ...      ...      ...              ...
# 8802   s8803    Movie    David Fincher
# 8803   s8804  TV Show    Not Available
# 8804   s8805    Movie  Ruben Fleischer
# 8805   s8806    Movie     Peter Hewitt
# 8806   s8807    Movie      Mozez Singh
#
# [9602 rows x 3 columns]

# %%
dir_data=dir_data.drop(dir_data[dir_data["director"]=="Not Available"].index,axis=0)
dir_data
# Out:
#      show_id     type         director
# 0         s1    Movie  Kirsten Johnson
# 2         s3  TV Show  Julien Leclercq
# 5         s6  TV Show    Mike Flanagan
# 6         s7    Movie    Robert Cullen
# 6         s7    Movie   José Luis Ucha
# ...      ...      ...              ...
# 8801   s8802    Movie  Majid Al Ansari
# 8802   s8803    Movie    David Fincher
# 8804   s8805    Movie  Ruben Fleischer
# 8805   s8806    Movie     Peter Hewitt
# 8806   s8807    Movie      Mozez Singh
#
# [6978 rows x 3 columns]

# %%
df_TV_season = df.loc[df["duration"].str.contains("Season")== True , "duration" ].value_counts().reset_index()[:10]  #filtering out top 10 values of TV shows using string.
df_TV_season.rename(columns = {"index" : "No_of_seasons" , "duration" : "Count"}, inplace = True) #renaming the columns
plt.figure(figsize=(20,8))
sns.barplot(y = "No_of_seasons" , x = "Count" , data = df_TV_season)
plt.title("Count of TV shows with their no of season")
plt.show()

# %% [markdown]
# #Observation
#   Most of the tv shows has only 1 seasons

# %% [markdown]
# Now we have to calculate top 10 countries for content in Netflix

# %%
# Lets check for top 10 countries
top_10_country = country_data["country"].value_counts().head(10).index
df_new = country_data.loc[country_data['country'].isin(top_10_country)]
df_new
# Out:
#      show_id     type        country
# 0         s1    Movie  United States
# 2         s3  TV Show  Not Available
# 3         s4  TV Show  Not Available
# 4         s5  TV Show          India
# 5         s6  TV Show  Not Available
# ...      ...      ...            ...
# 8802   s8803    Movie  United States
# 8803   s8804  TV Show  Not Available
# 8804   s8805    Movie  United States
# 8805   s8806    Movie  United States
# 8806   s8807    Movie          India
#
# [8209 rows x 3 columns]

# %%
x = df_new.groupby(['country' , 'type'])['show_id'].count().reset_index()
x.pivot(index = 'country' , columns = 'type' , values = 'show_id').sort_values('Movie',ascending = False)
# Out:
# type            Movie  TV Show
# country
# United States    2752      932
# India             962       84
# United Kingdom    534      271
# Not Available     440      390
# Canada            319      126
# France            303       90
# Germany           182       44
# Spain             171       61
# Japan             119      198
# South Korea        61      170

# %%
plt.figure(figsize= (8,5))
sns.countplot(data = df_new , x = 'country' , order = top_10_country , hue = 'type')
plt.xticks(rotation = 90 , fontsize = 12)
plt.ylabel('total_movies/TV shows' , fontsize = 12)
plt.xlabel('')
plt.title('Total_movies/TVshows_by_country')
plt.show()

# %% [markdown]
# #Observation
#   From this analysis we can say that movie and tv shows most of them are made by United States. In the 2nd position holder it is India.

# %% [markdown]
# ###Bivariate Analysis

# %%
df_datetime = pd.DataFrame(df)
df_datetime['Year'] = df.date_added.dt.year
df_datetime['month'] = df.date_added.dt.month
df_datetime['day'] = df.date_added.dt.day_name()
df_datetime_month = df_datetime.sort_values(by ="month")
df_datetime_month['month_name'] = df.date_added.dt.month_name()

# %%
#check number of content present in netflix monthly basis
plt.figure(figsize=(20,8)) #defining fig size fot the graph image
sns.countplot(x = "month_name" , data = df_datetime_month , hue = "type")
plt.title("No of movies and TV series added monthwise") #title name of the plot
plt.legend(loc=(1.01,0.5))
plt.show()

# %% [markdown]
# #observation
#  From here we can say that july and December are the most of the contents were published in Netflix.
#
#  In the all the months number of uploaded movies is greater than tv_shows always.

# %%
plt.figure(figsize=(15,8))
sns.countplot(x = "day" , data = df_datetime , hue = "type" ,  order=["Monday" , "Tuesday" , "Wednesday", "Thursday", "Friday", "Saturday" ,"Sunday"])
plt.title("No of movies and TV series added daywise")
plt.show()

# %% [markdown]
# #observation
#    Most of the movies and tv shows are released in friday in Netflix.
#    after friday it is Thrusday.

# %% [markdown]
# Now We have to check all the ratings for Netflix Data Analysis.

# %%
df_rating = df[df["rating"].isnull()== False]
df_rating.reset_index(inplace = True)
plt.figure(figsize=(20,8))
sns.countplot(x ="rating" , data = df_rating , hue = "type")
plt.show()

# %% [markdown]
# #Observation
#    Most of the ratings are presented in the form of TV-MA and TV-14.
#
# PG-13 -----> Parental Guidance with Adult Themes[Parental Guidance]
# TV-MA -----> Mature Audience[Only for Adults]
# PG -----> Parental Guidance without Adult Themes[Parental Guidance]
# TV-14 -----> Contents with Parents strongly cautioned
# TV-PG -----> Parental guide suggested[Parental Guidance]
# TV-Y -----> Children suited content[General Audience & Kids]
# TV-Y7 -----> Children of age 7 and older[General Audience & Kids]
# R -----> Strictly for Adults[Only for Adults]
# TV-G -----> Suitable for all audiences[General Audience & Kids]
# G -----> General Audience films[General Audience & Kids]
# NC-17 -----> No one seventeen and under admitted[Only for Adults]
# NR -----> Not rated movies[Not Rated]
# TV-Y7-FV -----> Children of age 7 and older with fantasy violence[General Audience & Kids]
# UR -----> recut version of rated movie[Not Rated]
#
# From this analysis we can say that most of the netflix contents are for the adults and watching with the parents permession for the mature audience.

# %%
#check top 10 genre of movies
top_10_movie_genres = genre_data[genre_data['type'] == 'Movie'].listed_in.value_counts().head(10).index
df_movie = genre_data.loc[genre_data['listed_in'].isin(top_10_movie_genres)]
top_10_TV_genres = genre_data[genre_data['type'] == 'TV Show'].listed_in.value_counts().head(10).index
df_tv = genre_data.loc[genre_data['listed_in'].isin(top_10_TV_genres)]

# %%
plt.figure(figsize= (8,4))
sns.countplot(data = df_movie , x = 'listed_in' , order = top_10_movie_genres)
plt.xticks(rotation = 90 , fontsize = 12)
plt.ylabel('total_movies' , fontsize = 12)
plt.xlabel('Genres' , fontsize = 12)
plt.title('Total_movies_by_genre')
plt.show()

# %% [markdown]
# #Observation
#    Most of the released movies genre are International Movies, Dramas,comedy

# %%
plt.figure(figsize= (8,4))
sns.countplot(data = df_tv , x = 'listed_in' , order = top_10_TV_genres)
plt.xticks(rotation = 90 , fontsize = 12)
plt.ylabel('total_TV_Shows' , fontsize = 12)
plt.xlabel('Genres' , fontsize = 12)
plt.title('Total_TV_Shows_by_genre')
plt.show()

# %% [markdown]
# Similarly in the tv shows most of the genres are international tvshows, tv
# dramas, tv comedies..

# %% [markdown]
# Lets check Genre by 20 popular countries

# %%
top_20_country = country_data["country"].value_counts().head(20).index
top_20_country = country_data.loc[country_data['country'].isin(top_20_country)]

# %%
x = top_20_country.merge(genre_data , on = 'show_id').drop_duplicates()
country_genre = x.groupby([ 'country' , 'listed_in'])['show_id'].count().sort_values(ascending = False).reset_index()
country_genre = country_genre.pivot(index = 'listed_in' , columns = 'country' , values = 'show_id')
country_genre
# Out:
# country                       Argentina  Australia  Brazil  Canada  China  \
# listed_in
# Action & Adventure                  3.0       13.0     5.0    44.0   63.0
# Anime Features                      NaN        NaN     NaN     NaN    2.0
# Anime Series                        NaN        1.0     NaN     2.0    2.0
# British TV Shows                    NaN        5.0     NaN     3.0    3.0
# Children & Family Movies            3.0       19.0     7.0    80.0   16.0
# Classic & Cult TV                   1.0        NaN     NaN     4.0    NaN
# Classic Movies                      1.0        5.0     NaN     NaN    NaN
# Comedies                           14.0       15.0    20.0    94.0   31.0
# Crime TV Shows                      8.0        7.0     6.0    15.0    4.0
# Cult Movies                         2.0        1.0     NaN     6.0    1.0
# Documentaries                      10.0       15.0    12.0    42.0    7.0
# ...

# %%
plt.figure(figsize = (12,10))
sns.heatmap(data = country_genre , annot = True , fmt=".0f" , vmin = 20 , vmax = 250 )
plt.xlabel('Countries' , fontsize = 12)
plt.ylabel('Genres' , fontsize = 12)
plt.title('Countries V/s Genres' , fontsize = 12)
# Out:
# Text(0.5, 1.0, 'Countries V/s Genres')

# %% [markdown]
# #Observation
#   Maximum International Movies are released in India.
#
#   UK and USA are good mix of all the genres of movie are released.
#   most common movie genres are Dramas,comedies,International movies,action and adeventures.
#
#   In some of the countries have their own language movies are very popular.
#   Maximum these country mainly has their own languages..

# %%
#top actors by country
x = cast_data.merge(country_data , on = 'show_id').drop_duplicates()
x = x.groupby(['country' , 'cast'])['show_id'].count().reset_index()
x.loc[x['country'].isin(['United States'])].sort_values('show_id' , ascending = False).head
# Out:
# <bound method NDFrame.head of              country               cast  show_id
# 50549  United States      Not Available      407
# 52326  United States  Samuel L. Jackson       22
# 53401  United States        Tara Strong       22
# 44458  United States    Fred Tatasciore       21
# 39728  United States       Adam Sandler       20
# ...              ...                ...      ...
# 45563  United States          Jadagrace        1
# 45564  United States        Jadah Marie        1
# 45565  United States        Jade Eshete        1
# 45566  United States      Jade Hassouné        1
# 54676  United States      Óscar Jaenada        1
#
# [15084 rows x 3 columns]>

# %%
x = cast_data.merge(country_data , on = 'show_id').drop_duplicates()
x = x.groupby(['country' , 'cast'])['show_id'].count().reset_index()
x.loc[x['country'].isin(['United States'])].sort_values('show_id' , ascending = False).head
# Out:
# <bound method NDFrame.head of              country               cast  show_id
# 50549  United States      Not Available      407
# 52326  United States  Samuel L. Jackson       22
# 53401  United States        Tara Strong       22
# 44458  United States    Fred Tatasciore       21
# 39728  United States       Adam Sandler       20
# ...              ...                ...      ...
# 45563  United States          Jadagrace        1
# 45564  United States        Jadah Marie        1
# 45565  United States        Jade Eshete        1
# 45566  United States      Jade Hassouné        1
# 54676  United States      Óscar Jaenada        1
#
# [15084 rows x 3 columns]>

# %%
country_list = ['India'  , 'United Kingdom' , 'Canada' , 'France' , 'Japan']
top_5_actors = x.loc[x['country'].isin(['United States'])].sort_values('show_id' , ascending = False).head(5)

# %%
for i in country_list:
    new = x.loc[x['country'].isin([i])].sort_values('show_id' , ascending = False).head(5)
    top_5_actors = pd.concat( [top_5_actors , new] , ignore_index = True)

# %%
top_5_actors
# Out:
#            country                  cast  show_id
# 0    United States         Not Available      407
# 1    United States     Samuel L. Jackson       22
# 2    United States           Tara Strong       22
# 3    United States       Fred Tatasciore       21
# 4    United States          Adam Sandler       20
# 5            India           Anupam Kher       40
# 6            India         Not Available       39
# 7            India        Shah Rukh Khan       34
# 8            India      Naseeruddin Shah       31
# 9            India               Om Puri       29
# 10  United Kingdom         Not Available       97
# 11  United Kingdom    David Attenborough       17
# 12  United Kingdom           John Cleese       16
# 13  United Kingdom         Michael Palin       14
# 14  United Kingdom           Terry Jones       12
# 15          Canada         Not Available       31
# 16          Canada    John Paul Tremblay       14
# 17          Canada            Robb Wells       14
# ...

# %% [markdown]
# here we wants to find all the top 5 actors of the different country who making highest no of movies apperence. but here we find not available data. now drop those column and find top actors in different country movies.

# %%
top_5_actors.drop(top_5_actors.index[(top_5_actors["cast"]=="Not Available")],axis=0,inplace=True)

# %%
top_5_actors
# Out:
#            country                  cast  show_id
# 1    United States     Samuel L. Jackson       22
# 2    United States           Tara Strong       22
# 3    United States       Fred Tatasciore       21
# 4    United States          Adam Sandler       20
# 5            India           Anupam Kher       40
# 7            India        Shah Rukh Khan       34
# 8            India      Naseeruddin Shah       31
# 9            India               Om Puri       29
# 11  United Kingdom    David Attenborough       17
# 12  United Kingdom           John Cleese       16
# 13  United Kingdom         Michael Palin       14
# 14  United Kingdom           Terry Jones       12
# 16          Canada    John Paul Tremblay       14
# 17          Canada            Robb Wells       14
# 18          Canada         Ashleigh Ball       12
# 19          Canada        John Dunsworth       12
# 21          France        Wille Lindberg        5
# 22          France        Benoît Magimel        5
# ...

# %% [markdown]
# It will provide different country movies in neyflix.

# %%
plt.figure(figsize = (12,8))
sns.barplot(data = top_5_actors , y = 'cast' , x = 'show_id' , hue = 'country')
# Out:
# <Axes: xlabel='show_id', ylabel='cast'>

# %% [markdown]
# now analysis of directors as per genre

# %%
#top 5 directors
genre_list = [ 'Children & Family Movies', 'Comedies','Dramas', 'International Movies', 'Documentaries' ,
              'International TV Shows', 'Sci-Fi & Fantasy', 'Thrillers', 'Horror Movies']

x = dir_data.merge(genre_data , on = 'show_id').groupby([ 'listed_in' , 'director',])['show_id'].count().reset_index()

top_5_dir = x.loc[x['listed_in'] == 'Action & Adventure'].sort_values('show_id' , ascending = False).head()

for i in genre_list:
    new = x.loc[x['listed_in'] == i].sort_values('show_id' , ascending = False).head()
    top_5_dir = pd.concat([top_5_dir , new])

top_5_dir
# Out:
#                       listed_in               director  show_id
# 147          Action & Adventure       Don Michael Paul        9
# 550          Action & Adventure         S.S. Rajamouli        7
# 651          Action & Adventure      Toshiya Shinohara        7
# 215          Action & Adventure         Hidenori Inoue        7
# 606          Action & Adventure       Steven Spielberg        5
# 1215   Children & Family Movies          Rajiv Chilaka       22
# 1303   Children & Family Movies            Suhas Kadav       16
# 1211   Children & Family Movies          Prakash Satam        7
# 1241   Children & Family Movies       Robert Rodriguez        7
# 1288   Children & Family Movies             Steve Ball        6
# 1756                   Comedies           David Dhawan        9
# 1905                   Comedies            Hakan Algül        8
# 2686                   Comedies            Suhas Kadav        8
# 2456                   Comedies          Prakash Satam        7
# ...

# %%
#top5 genre of each country
x = genre_data.merge(country_data , on = 'show_id').drop_duplicates()
x = x.groupby(['country' , 'listed_in'])['show_id'].count().reset_index()
x.loc[x['country'] == 'United States'].sort_values('show_id' , ascending = False).head(5)

country_list = ['India'  , 'United Kingdom' , 'Canada' , 'France' , 'Japan']
top_5_genre = x.loc[x['country'].isin(['United States'])].sort_values('show_id' , ascending = False).head(5)

for i in country_list:
    new = x.loc[x['country'] == i].sort_values('show_id' , ascending = False).head(5)
    top_5_genre = pd.concat( [top_5_genre , new] , ignore_index = True)
top_5_genre
# Out:
#            country                 listed_in  show_id
# 0    United States                    Dramas      835
# 1    United States                  Comedies      680
# 2    United States             Documentaries      512
# 3    United States        Action & Adventure      404
# 4    United States        Independent Movies      390
# 5            India      International Movies      864
# 6            India                    Dramas      662
# 7            India                  Comedies      323
# 8            India        Independent Movies      167
# 9            India        Action & Adventure      137
# 10  United Kingdom          British TV Shows      224
# 11  United Kingdom                    Dramas      197
# 12  United Kingdom      International Movies      170
# 13  United Kingdom    International TV Shows      128
# 14  United Kingdom             Documentaries      128
# 15          Canada                  Comedies       94
# ...

# %% [markdown]
# Movies duration in past years comparisons

# %%
plt.figure(figsize = (12,8))
sns.scatterplot(x=movies["duration_in_minutes"],y=movies['release_year'],alpha=0.5)
plt.xlim((0,200))
# Out:
# (0.0, 200.0)

# %% [markdown]
# #Observation
#  The movies released after 2000, duration are drastically low to under 150 minutes.
#
#  After 2010 there is a jump in the movies which are shorter than 75 minutes.

# %% [markdown]
# Which country added more movies year wise

# %%
country_list = country_data.country.value_counts().head(12).index
top_12_country = country_data.loc[country_data['country'].isin(country_list)]
country_year = top_12_country.merge(df , on = 'show_id')[['show_id','country_x' ,'type_x' , 'year' ]]
country_year.columns = ['show_id', 'country', 'type', 'year']
country_year = country_year.groupby(['country' , 'year'])['show_id'].count().reset_index()
plt.figure(figsize = (10,6))
sns.lineplot(data = country_year , x = 'year' , y = 'show_id' , hue = 'country' , palette ='rainbow' )
# Out:
# <Axes: xlabel='year', ylabel='show_id'>

# %% [markdown]
# #Observation
#  Usa make highest number of movies all the times.
#
#  after 2016 ,India has a spike in making contents for netflix, followed by united kingdom.

# %%
# Out:
#           country  year  show_id
# 0          Canada  2013        1
# 1          Canada  2014        3
# 2          Canada  2015        6
# 3          Canada  2016       30
# 4          Canada  2017       71
# ..            ...   ...      ...
# 92  United States  2017      462
# 93  United States  2018      600
# 94  United States  2019      856
# 95  United States  2020      828
# 96  United States  2021      627
#
# [97 rows x 3 columns]

# %%
country_list = country_data.country.value_counts().head(12).index
top_12_country = country_data.loc[country_data['country'].isin(country_list)]
country_year = top_12_country.merge(df , on = 'show_id')[['show_id','country_x' ,'type_x' , 'year' ]]
country_year.columns = ['show_id', 'country', 'type', 'year']
country_year = country_year.groupby(['country' , 'year'])['show_id'].count().reset_index()
plt.figure(figsize = (10,6))
sns.lineplot(data = country_year , x = 'year' , y = 'show_id' , hue = 'country' , palette ='rainbow' )
# Out:
# <Axes: xlabel='year', ylabel='show_id'>

# %%
country_year = top_12_country.merge(df , on = 'show_id')[['show_id','country_x' ,'type_x' , 'year' ]]
country_year.columns = ['show_id', 'country', 'type', 'year']

# %%
movie_type = country_year.loc[country_year["type"]== 'Movie'].groupby(['country' , 'year'])['show_id'].count().reset_index()
tv_type = country_year.loc[country_year["type"] == 'TV Show'].groupby(['country' , 'year'])['show_id'].count().reset_index()
plt.figure(figsize = (10,6))
sns.lineplot(data = movie_type , x = 'year' , y = 'show_id' , hue = 'country' , palette ='rainbow' )
# Out:
# <Axes: xlabel='year', ylabel='show_id'>

# %%
plt.figure(figsize = (10,6))
sns.lineplot(data = tv_type , x = 'year' , y = 'show_id' , hue = 'country' , palette ='rainbow' )
# Out:
# <Axes: xlabel='year', ylabel='show_id'>

# %% [markdown]
# In both the case USA are making more movies and tv shows than any other countries. But still from 2016 there is a hike in India to make movies for Netflix. second position to make tv shows are united kingdom.

# %% [markdown]
# ###Insights based on Non-Graphical and Visual Analysis###
#
#  1. There is a huge gaps in content of Netflix, approximately 70 percent content is movies and other 30 percent are tv shows.
#
#  2. The movies and TV shows uploading on the Netflix started from the year 2008, It had very lesser content till 2014.Contents are there from 1925 but they are very less.
#
#  3. Year 2015 move to a jump in the content getting uploaded on Netflix. It continues to 2019 marks the highest number of movies and TV shows added on the Netflix. Year 2020 and 2021 has seen the drop in content added on Netflix, possibly because of Pandemic. But still , TV shows content have not dropped as drastic as movies.
# Since 2018, A drop in the movies is seen , but rise in TV shows is observed clearly. Being in continuous uptrend , TV shows surpassed the movies count in mid 2020. It shows the rise in popularity of tv shows in recent years.
# Netflix has movies from variety of directors. Around 4993 directors have their movies or tv shows on Netflix.
# Netflix has movies from total 122 countries, United States being the highset contributor with almost 37% of all the content.
# The release year for shows is concentrated in the range 2005-2021.
# 50 mins - 150 mins is the range of movie durations, excluding potential outliers.
# 1-3 seasons is the range for TV shows seasons, excluding potential outliers.
# various ratings of content is avaialble on netfilx, for the various viewers categories like kids, adults , families. Highest number of movies and TV shows are rated TV-MA (for mature audiences).
# Content in most of the ratings is available in lesser quanitity except in US. Ratings like TV-Y7 , TV-Y7 FV , PG ,TV-G , G , TV-Y , TV-PG are very less avaialble in all countries except US.
# International Movies and TV Shows , Dramas , and Comedies are the top 3 genres on Netflix for both Movies and TV shows.
# Mostly country specific popular genres are observed in each country. Only United States have a good mix of almost all genres. Eg. Korean TV shows (Korea), British TV Shows (UK), Anime features and Anime series (Japan) and so on.
# Indian Actors have been acted in maximum movies on netflix. Top 5 actors are in India based on quantity of movies.
# Shorter duration movies have been popular in last 10 years.
#  4. Since 2018, A drop in the movies is seen , but rise in TV shows is observed clearly. Being in continuous uptrend , TV shows surpassed the movies count in mid 2020. It shows the rise in popularity of tv shows in recent years.
#
#  5. Netflix has movies from variety of directors. Around 4993 directors have their movies or tv shows on Netflix.
#  6.  Netflix has movies from total 122 countries, United States being the highset contributor with almost 37% of all the content.
#  7. The release year for shows is concentrated in the range 2005-2021.
#  50 mins - 150 mins is the range of ovie durations, excluding potential outliers.
#  8. 1-3 seasons is the range for TV shows seasons, excluding potential outliers.
#  9. various ratings of content is avaialble on netfilx, for the various viewers categories like kids, adults , families. Highest number of movies and TV shows are rated TV-MA (for mature audiences).
#  10. Content in most of the ratings is available in lesser quanitity except in US. Ratings like TV-Y7 , TV-Y7 FV , PG ,TV-G , G , TV-Y , TV-PG are very less avaialble in all countries except US.
#  11. International Movies and TV Shows , Dramas , and Comedies are the top 3 genres on Netflix for both Movies and TV shows.
#  12. country specific popular genres are observed in each country. Only United States have a good mix of almost all genres. Eg. Korean TV shows (Korea), British TV Shows (UK), Anime features and Anime series (Japan) and so on.
#  13. Indian Actors have been acted in maximum movies on netflix. Top 5 actors are in India based on quantity of movies.
#  14. Shorter duration movies have been popular in last 10 years.

# %% [markdown]
# ###Business Insights

# %% [markdown]
# 1. Netflix have majority of content which is released after the year 2000. It is observed that the content older than year 2000 is very scarce on Netflix. Senior Citizen could be the target audience for such content, which is almost missing currently.
#
# 2. Maximum content is for Adult.
#    TV-MA - Content intended for mature audiences aged 17 and above.
#    TV-14 - Content suitable for viewers aged 14 and above.
#    TV-PG - Parental guidance suggested (similar ratings - PG-13 , PG)
#    R - Restricted Content, that may not be suitable for viewers under age 17.
#
# 3. These ratings' movies target Matured and Adult audience. Rest 20 % of the content is for kids aged below 13. It shows that Netflix is currently serving mostly Mature audiences or Children with parental guidance.
#
# 4. Most popular genres on Netflix are International Movies and TV Shows , Dramas , Comedies, Action & Adventure, Children & Family Movies, Thrillers.
# Maximum content of Netflix which is around 75% , is coming from the top 10 countries. Rest of the world only contributes 25% of the content. More countries can be focussed in future to grow the business.
#
# 5. Liking towards the shorter duration content is on the rise. (duration 75 to 150 minutes and seasons 1 to 3)
# This can be considered while production of new content on Netflix.
#
# 6. Drop in content is seen across all the countries and type of content in year 2020 and 2021, possibly because of Pandemic.

# %% [markdown]
# ###Recommendations :
#
# *Movies* :-
#
#  Preferd movies duration is between 90-100 minutes.
#
#  Netflix should add more movies for United States and India falling in category of Internation movies and comedies.
#
#  Netflix should add more movies for United States and India having rating of TV-MA & TV-14.
#
#  Top three countries where movies added are United States, India & United Kingdom.
#
#  Netflix shoud add TV Show on Friday than any other weekday.
#
# *TV Show*:-
#
#  Preferd movies duration is 1-2 seeasons.
#
#  Netflix should focus on countries like Japan, South Korea and France in TV shows , as they prefer TV shows over movies.
#
#  Netflix shoud add TV Show on Friday than other weekday.
#
#  As per 2021 data, count of TV showes are more than movies , this means people wants more web-series as they have for leisure time may be due to work from home scenario.
